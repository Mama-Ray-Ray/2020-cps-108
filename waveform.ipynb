# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import scipy.io.wavfile
rate, samples = scipy.io.wavfile.read('music.wav')
plot(samples)

# %%
a = [4, 5, 6]
print(a)
# Out:
# [4, 5, 6]

# %%
for item in a:
    print(item)
# Out:
# 4
# 5
# 6

# %%
a.append(7)
print(a)
# Out:
# [4, 5, 6, 7]
